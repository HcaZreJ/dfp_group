# %%
import pandas as pd

injury = pd.read_csv("injured_reserve_2023.csv", header=0)

injury
# Out:
#         Player (206) Pos. Team           Injury  Games  \
# 0       Bradley Beal   SG  PHX             Back     17
# 1        Ben Simmons   PG  BKN         Back/Hip     13
# 2      Stephen Curry   PG  GSW             Knee      2
# 3    Anfernee Simons   SG  POR            Thumb     18
# 4       Jamal Murray   PG  DEN  Hamstring/Ankle     13
# ..               ...  ...  ...              ...    ...
# 202         Jay Huff    C  DEN             Ribs      4
# 203       Keon Ellis   SF  SAC            Ankle      3
# 204       Jamal Cain   SF  MIA          Illness      1
# 205    Justin Minaya    F  POR          Illness      1
# 206              NaN  NaN  NaN              NaN   1216
#
#      Cash EarnedWhile Injured
# 0                     9133420
# 1                     6097784
# 2                     5967320
# 3                     5264786
# 4                     5055570
# ..                        ...
# 202                         0
# 203                         0
# ...

# %%
injury[injury["Games"] > 10]
# Out:
#             Player (206) Pos. Team           Injury  Games  \
# 0           Bradley Beal   SG  PHX             Back     17
# 1            Ben Simmons   PG  BKN         Back/Hip     13
# 3        Anfernee Simons   SG  POR            Thumb     18
# 4           Jamal Murray   PG  DEN  Hamstring/Ankle     13
# 5          C.J. McCollum   SG  NOP             Lung     12
# 6             Lonzo Ball   PG  CHI             Knee     21
# 7       Bojan Bogdanovic   SF  DET             Calf     19
# 9            Tyler Herro   SG  MIA            Ankle     12
# 11            Joe Harris   SG  DET         Shoulder     13
# 12        Markelle Fultz   PG  ORL             Knee     15
# 13          Steven Adams    C  MEM             Knee     19
# 14        Brandon Clarke   PF  MEM         Achilles     19
# 17          Monte Morris   PG  DET             Quad     20
# 18    Wendell Carter Jr.    C  ORL           Finger     15
# 21        Victor Oladipo   SG  HOU             Knee     17
# ...
